# %% [markdown]
# <a href="https://colab.research.google.com/github/sharat2000/SHARAT-RAJ/blob/main/cancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/cancer_death_rate/Training_set_label.csv")

# %%
data
# Out:
#       avgAnnCount  avgDeathsPerYear  ...  BirthRate  TARGET_deathRate
# 0       19.000000                 8  ...  15.157116             160.3
# 1       88.000000                34  ...   3.293510             194.9
# 2      195.000000                83  ...   6.390328             196.5
# 3      116.000000                55  ...   5.124836             230.9
# 4       80.000000                35  ...   3.897033             162.2
# ...           ...               ...  ...        ...               ...
# 3046    58.000000                24  ...   4.152249             146.2
# 3047    63.000000                25  ...   6.256983             183.7
# 3048  1962.667684                 7  ...   9.725159             128.7
# 3049    85.000000                48  ...   6.283214             209.2
# 3050    55.000000                27  ...  10.046948             167.7
#
# [3051 rows x 34 columns]

# %%
data[data['TARGET_deathRate']<100].count
# Out:
# <bound method DataFrame.count of       avgAnnCount  avgDeathsPerYear  ...  BirthRate  TARGET_deathRate
# 573      1.949390          1.322219  ...   7.863132              94.4
# 654      1.322219          0.845098  ...   6.324111              66.3
# 1521     2.139879          1.414973  ...   4.860486              80.8
#
# [3 rows x 30 columns]>

# %%
data=data.drop_duplicates()

# %%
data.shape
# Out:
# (2285, 30)

# %%
data.dtypes
# Out:
# avgAnnCount                float64
# avgDeathsPerYear             int64
# incidenceRate              float64
# medIncome                    int64
# popEst2015                   int64
# povertyPercent             float64
# studyPerCap                float64
# binnedInc                   object
# MedianAge                  float64
# MedianAgeMale              float64
# MedianAgeFemale            float64
# Geography                   object
# AvgHouseholdSize           float64
# PercentMarried             float64
# PctNoHS18_24               float64
# PctHS18_24                 float64
# PctSomeCol18_24            float64
# PctBachDeg18_24            float64
# PctHS25_Over               float64
# PctBachDeg25_Over          float64
# PctEmployed16_Over         float64
# PctUnemployed16_Over       float64
# PctPrivateCoverage         float64
# PctPrivateCoverageAlone    float64
# PctEmpPrivCoverage         float64
# PctPublicCoverage          float64
# PctPublicCoverageAlone     float64
# ...

# %%
data.nunique()
# Out:
# avgAnnCount                 779
# avgDeathsPerYear            513
# incidenceRate              1264
# medIncome                  2208
# popEst2015                 2253
# povertyPercent              313
# studyPerCap                 837
# binnedInc                    10
# MedianAge                   295
# MedianAgeMale               284
# MedianAgeFemale             279
# Geography                  2285
# AvgHouseholdSize            184
# PercentMarried              345
# PctNoHS18_24                384
# PctHS18_24                  440
# PctSomeCol18_24             301
# PctBachDeg18_24             212
# PctHS25_Over                352
# PctBachDeg25_Over           267
# PctEmployed16_Over          385
# PctUnemployed16_Over        183
# PctPrivateCoverage          467
# PctPrivateCoverageAlone     434
# PctEmpPrivCoverage          425
# PctPublicCoverage           375
# PctPublicCoverageAlone      300
# PctWhite                   2284
# PctBlack                   2230
# ...

# %%
data.describe()
# Out:
#         avgAnnCount  avgDeathsPerYear  ...    BirthRate  TARGET_deathRate
# count   2285.000000       2285.000000  ...  2285.000000       2285.000000
# mean     571.234205        174.378993  ...     5.608094        178.634048
# std     1190.111708        421.262817  ...     1.958079         27.381280
# min        6.000000          3.000000  ...     0.000000         66.300000
# 25%       78.000000         29.000000  ...     4.497369        161.300000
# 50%      174.000000         62.000000  ...     5.389798        178.100000
# 75%      512.000000        149.000000  ...     6.469649        195.200000
# max    24965.000000       9445.000000  ...    21.326165        362.800000
#
# [8 rows x 32 columns]

# %%
data.corr()
# Out:
#                          avgAnnCount  ...  TARGET_deathRate
# avgAnnCount                 1.000000  ...         -0.138106
# avgDeathsPerYear            0.911926  ...         -0.075079
# incidenceRate               0.097013  ...          0.469213
# medIncome                   0.304332  ...         -0.431586
# popEst2015                  0.896032  ...         -0.115593
# povertyPercent             -0.165171  ...          0.428083
# studyPerCap                 0.074347  ...         -0.029654
# MedianAge                  -0.024655  ...          0.006193
# MedianAgeMale              -0.119419  ...         -0.005364
# MedianAgeFemale            -0.120818  ...          0.030528
# AvgHouseholdSize            0.055054  ...         -0.037925
# PercentMarried             -0.090218  ...         -0.274256
# PctNoHS18_24               -0.161578  ...          0.076309
# PctHS18_24                 -0.189216  ...          0.284848
# PctSomeCol18_24             0.148383  ...         -0.216487
# ...

# %%
data.drop(['binnedInc','Geography','studyPerCap','PctSomeCol18_24'],axis=1,inplace=True)

# %%
data.shape
# Out:
# (2285, 30)

# %%
data['PctPrivateCoverageAlone'].fillna(data['PctPrivateCoverageAlone'].median(),inplace=True)
data['PctEmployed16_Over'].fillna(data['PctEmployed16_Over'].median(),inplace=True)

# %%
test_data = pd.read_csv('https://raw.githubusercontent.com/dphi-official/Datasets/master/cancer_death_rate/Testing_set_label.csv')
test_data.head()
# Out:
#    avgAnnCount  avgDeathsPerYear  ...  PctMarriedHouseholds  BirthRate
# 0  2092.000000               763  ...             56.335344   6.825886
# 1    94.000000                41  ...             55.288859   2.292861
# 2   126.000000                43  ...             52.614465  10.502567
# 3  1962.667684                16  ...             55.044700   9.342231
# 4  1962.667684                 4  ...             47.826087  10.029499
#
# [5 rows x 33 columns]

# %%
test_data
# Out:
#      avgAnnCount  avgDeathsPerYear  ...  PctMarriedHouseholds  BirthRate
# 0       3.320562          2.882525  ...             56.335344   6.825886
# 1       1.973128          1.612784  ...             55.288859   2.292861
# 2       2.100371          1.633468  ...             52.614465  10.502567
# 3       3.292847          1.204120  ...             55.044700   9.342231
# 4       3.292847          0.602060  ...             47.826087  10.029499
# ..           ...               ...  ...                   ...        ...
# 757     2.181844          1.845098  ...             53.063790   4.220288
# 758     2.344392          1.929419  ...             57.149659   4.006755
# 759     2.269513          1.968483  ...             48.108966   4.012841
# 760     2.557507          2.143015  ...             45.683849   5.051532
# 761     1.176091          0.845098  ...             64.061410   5.249680
#
# [762 rows x 29 columns]

# %%
test_data[test_data['MedianAge']>100].count
# Out:
# <bound method DataFrame.count of      avgAnnCount  avgDeathsPerYear  ...  PctMarriedHouseholds  BirthRate
# 4       3.292847          0.602060  ...             47.826087  10.029499
# 55      2.917506          2.514548  ...             46.795028   4.493937
# 162     2.883661          2.423246  ...             52.945686   3.127102
# 243     1.544068          1.079181  ...             46.769034   3.333333
# 271     2.539076          2.193125  ...             51.591360   4.194566
# 340     1.322219          1.079181  ...             51.515152   8.121019
# 374     2.884229          2.447158  ...             49.226681   5.488942
# 642     1.397940          1.000000  ...             36.829268   6.625097
# 752     1.681241          1.230449  ...             47.560976   2.939068
# 759     2.269513          1.968483  ...             48.108966   4.012841
#
# [10 rows x 29 columns]>

# %%
test_data=test_data.drop_duplicates()

# %%
test_data.shape
# Out:
# (762, 33)

# %%
test_data.describe()
# Out:
#        avgAnnCount  avgDeathsPerYear  ...  PctMarriedHouseholds   BirthRate
# count   762.000000        762.000000  ...            762.000000  762.000000
# mean      2.307861          1.827525  ...             50.926053    5.736898
# std       0.661509          0.605558  ...              6.800150    2.065069
# min       0.845098          0.477121  ...             22.992490    0.000000
# 25%       1.832509          1.414973  ...             47.607275    4.608878
# 50%       2.210851          1.778151  ...             51.336903    5.367187
# 75%       2.728951          2.178948  ...             55.208111    6.583930
# max       4.581495          4.146438  ...             78.075397   18.556701
#
# [8 rows x 29 columns]

# %%
test_data.boxplot(column=['MedianAge'])

# %%
test_data.isnull().sum()
# Out:
# avgAnnCount                0
# avgDeathsPerYear           0
# incidenceRate              0
# medIncome                  0
# popEst2015                 0
# povertyPercent             0
# MedianAge                  0
# MedianAgeMale              0
# MedianAgeFemale            0
# AvgHouseholdSize           0
# PercentMarried             0
# PctNoHS18_24               0
# PctHS18_24                 0
# PctBachDeg18_24            0
# PctHS25_Over               0
# PctBachDeg25_Over          0
# PctEmployed16_Over         0
# PctUnemployed16_Over       0
# PctPrivateCoverage         0
# PctPrivateCoverageAlone    0
# PctEmpPrivCoverage         0
# PctPublicCoverage          0
# PctPublicCoverageAlone     0
# PctWhite                   0
# PctBlack                   0
# PctAsian                   0
# PctOtherRace               0
# PctMarriedHouseholds       0
# BirthRate                  0
# dtype: int64

# %%
test_data['PctPrivateCoverageAlone'].fillna(test_data['PctPrivateCoverageAlone'].median(),inplace=True)
test_data['PctEmployed16_Over'].fillna(test_data['PctEmployed16_Over'].median(),inplace=True)

# %%
test_data.drop(['binnedInc','Geography','studyPerCap','PctSomeCol18_24'],axis=1,inplace=True)

# %%
test_data.shape
# Out:
# (762, 29)

# %%
data
# Out:
#       avgAnnCount  avgDeathsPerYear  ...  BirthRate  TARGET_deathRate
# 1            88.0                34  ...   3.293510             194.9
# 2           195.0                83  ...   6.390328             196.5
# 3           116.0                55  ...   5.124836             230.9
# 4            80.0                35  ...   3.897033             162.2
# 5            49.0                24  ...   2.790179             219.7
# ...           ...               ...  ...        ...               ...
# 2280       1395.0               490  ...   4.844987             176.0
# 2281         43.0                17  ...   6.959707             166.4
# 2282         60.0                25  ...   6.866667             161.7
# 2283        344.0               134  ...   6.920828             186.0
# 2284        242.0               113  ...   7.936655             201.9
#
# [2195 rows x 30 columns]

# %%
data['avgAnnCount']=np.log10(data['avgAnnCount'])

# %%
test_data['avgAnnCount']=np.log10(test_data['avgAnnCount'])

# %%
data['avgDeathsPerYear']=np.log10(data['avgDeathsPerYear'])

# %%
test_data['avgDeathsPerYear']=np.log10(test_data['avgDeathsPerYear'])

# %%
data['incidenceRate']=data['incidenceRate']/100

# %%
test_data['incidenceRate']=test_data['incidenceRate']/100

# %%
data['medIncome']=data['medIncome']/1000

# %%
test_data['medIncome']=test_data['medIncome']/1000

# %%
data['popEst2015']=np.log10(data['popEst2015'])

# %%
test_data['popEst2015']=np.log10(test_data['popEst2015'])

# %%
data.boxplot(column=['MedianAgeMale','MedianAgeFemale','MedianAge'])

# %%
X[X['MedianAge']>100].count
# Out:
# <bound method DataFrame.count of       avgAnnCount  avgDeathsPerYear  ...  PctMarriedHouseholds  BirthRate
# 158      2.981819          2.599883  ...             41.830737   5.131499
# 181      1.949390          1.505150  ...             60.491493   9.675646
# 349      2.751279          2.274158  ...             51.876656   5.497053
# 405      2.380211          1.977724  ...             50.062526   6.037875
# 642      2.448706          2.049218  ...             53.986783   5.772258
# 693      2.361728          1.991226  ...             45.407268   6.140351
# 847      1.397940          1.146128  ...             54.647721   5.076142
# 880      2.945961          2.517196  ...             57.019535   6.809809
# 1031     1.977724          1.505150  ...             43.591303   4.200665
# 1050     2.777427          2.397940  ...             45.456544   3.432793
# 1221     2.743510          2.357935  ...             51.820289   6.903027
# ...

# %%
data=data[data['MedianAge']<100]

# %%
test_data.boxplot(column=['MedianAgeMale','MedianAgeFemale','MedianAge'])

# %%
test_data=test_data[test_data['MedianAge']<100]

# %%
test_data.boxplot(column=['AvgHouseholdSize',	'PercentMarried',	'PctNoHS18_24',	'PctHS18_24','PctBachDeg18_24',	'PctHS25_Over',	'PctBachDeg25_Over'	])

# %%
X['PctPrivateCoverageAlone'].isnull().sum()

# %%
X['PctPrivateCoverageAlone'].fillna(X['PctPrivateCoverageAlone'].median(),inplace=True)
X['PctEmployed16_Over'].fillna(X['PctEmployed16_Over'].median(),inplace=True)

# %%
X
# Out:
#       avgAnnCount  avgDeathsPerYear  ...  PctMarriedHouseholds  BirthRate
# 0        1.278754          0.903090  ...             62.511457  15.157116
# 1        1.944483          1.531479  ...             61.641045   3.293510
# 2        2.290035          1.919078  ...             53.978102   6.390328
# 3        2.064458          1.740363  ...             51.013143   5.124836
# 4        1.903090          1.544068  ...             50.566426   3.897033
# ...           ...               ...  ...                   ...        ...
# 2280     3.144574          2.690196  ...             40.848654   4.844987
# 2281     1.633468          1.230449  ...             62.553613   6.959707
# 2282     1.778151          1.397940  ...             54.790097   6.866667
# 2283     2.536558          2.127105  ...             43.388111   6.920828
# 2284     2.383815          2.053078  ...             51.015621   7.936655
#
# [2265 rows x 29 columns]

# %%
X.boxplot(column=['PctWhite',	'PctBlack',	'PctAsian',	'PctOtherRace'])

# %%
X.boxplot(column=['PctMarriedHouseholds',	'BirthRate'])

# %%
test_data.boxplot(column=['PctWhite',	'PctBlack',	'PctAsian',	'PctOtherRace'])

# %%
test_data.boxplot(column=['PctMarriedHouseholds',	'BirthRate'])

# %%
data.shape
# Out:
# (2215, 30)

# %%
data.isnull().sum()

# %%
data=data[data['PctBlack']<70]

# %%
data=data[data['PctWhite']>20]

# %%
data=data[data['PctAsian']<15]
data=data[data['PctOtherRace']<20]

# %%
data=data[data['PctMarriedHouseholds']<70]
data=data[data['BirthRate']<15]

# %%
data=data[data['PctBachDeg18_24']<20]

# %%
test_data=test_data[test_data['PctBlack']<80]

# %%
test_data=test_data[test_data['PctAsian']<20]
test_data=test_data[test_data['PctOtherRace']<20]

# %%
test_data=test_data[test_data['PctBachDeg18_24']<20]

# %%
test_data=test_data[test_data['PctMarriedHouseholds']<70]
test_data=test_data[test_data['BirthRate']<15]

# %%
X=data.iloc[:,0:29]
Y=data.iloc[:,29]

# %%
X.shape ,test_data.shape
# Out:
# ((2169, 29), (762, 29))

# %%
test_data.head()
# Out:
#    avgAnnCount  avgDeathsPerYear  ...  PctMarriedHouseholds  BirthRate
# 0     3.320562          2.882525  ...             56.335344   6.825886
# 1     1.973128          1.612784  ...             55.288859   2.292861
# 2     2.100371          1.633468  ...             52.614465  10.502567
# 3     3.292847          1.204120  ...             55.044700   9.342231
# 4     3.292847          0.602060  ...             47.826087  10.029499
#
# [5 rows x 29 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_val,Y_train,Y_val=train_test_split(X,Y,test_size = 0.33,random_state =1)

# %%
from sklearn.linear_model import LinearRegression
base_model1=LinearRegression(normalize=False, n_jobs=-1, fit_intercept=True, copy_X=True)
base_model1.fit(X_train,Y_train)
pred=base_model1.predict(X_val)
pred11=base_model1.predict(X_train)

# %%
from sklearn.linear_model import LinearRegression
model1=LinearRegression()
model1.fit(X_train,Y_train)
pre=model1.predict(X_val)
pred11=model1.predict(X_train)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(Y_val,pre)
# Out:
# 155.47575930462125

# %%
mean_squared_error(Y_train,pred11)
# Out:
# 144.47734928007966

# %%
test_data["MedianAge"] = np.where(test_data["MedianAge"]>=57,41.1,test_data['MedianAge'])

# %%
test_data["PctBlack"] = np.where(test_data["PctBlack"]>=70,np.median(test_data["PctBlack"]),test_data["PctBlack"])
test_data["PctWhite"] = np.where(test_data["PctWhite"]<=20,np.median(test_data["PctWhite"]),test_data["PctWhite"])
test_data["PctAsian"] = np.where(test_data["PctAsian"]>=15,np.median(test_data["PctAsian"]),test_data["PctAsian"])

# %%
test_data[test_data["PctWhite"]<=20].count
# Out:
# <bound method DataFrame.count of Empty DataFrame
# Columns: [avgAnnCount, avgDeathsPerYear, incidenceRate, medIncome, popEst2015, povertyPercent, MedianAge, MedianAgeMale, MedianAgeFemale, AvgHouseholdSize, PercentMarried, PctNoHS18_24, PctHS18_24, PctBachDeg18_24, PctHS25_Over, PctBachDeg25_Over, PctEmployed16_Over, PctUnemployed16_Over, PctPrivateCoverage, PctPrivateCoverageAlone, PctEmpPrivCoverage, PctPublicCoverage, PctPublicCoverageAlone, PctWhite, PctBlack, PctAsian, PctOtherRace, PctMarriedHouseholds, BirthRate]
# Index: []>

# %%
=np.median(test_data['MedianAge'])
# Out:
# 41.1

# %%
test_data['PctBlack'].value_counts()
# Out:
# 0.000000     18
# 2.120925      5
# 0.378788      2
# 0.059189      1
# 2.496484      1
#              ..
# 0.655572      1
# 0.160146      1
# 4.726467      1
# 0.818750      1
# 47.290093     1
# Name: PctBlack, Length: 740, dtype: int64

# %%
sub000=base_model1.predict(test_data)

# %%
submission=pd.DataFrame({'prediction':sub000})

# %%
submission2=pd.DataFrame({'prediction':sub2})

# %%
submission
# Out:
#      prediction
# 0    132.211673
# 1    187.980355
# 2    140.570410
# 3    166.721400
# 4    164.557032
# ..          ...
# 757  219.295362
# 758  191.479437
# 759  221.489475
# 760  201.909340
# 761  153.200047
#
# [762 rows x 1 columns]

# %%
submission.to_csv('CANCER000.csv',index=False)

# %%
from sklearn.feature_selection import RFE
rfe=RFE(estimator=model1,step=1,n_features_to_select=22)
fit=rfe.fit(X_train,Y_train)

# %%
fit.n_features_,fit.ranking_
# Out:
# (22, array([1, 1, 1, 1, 1, 1, 8, 1, 1, 1, 7, 6, 1, 4, 1, 1, 1, 1, 1, 1, 1, 1,
#         1, 3, 5, 1, 1, 2, 1]))

# %%
fit.set_params
# Out:
# <bound method BaseEstimator.set_params of RFE(estimator=LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                normalize=False),
#     n_features_to_select=None, step=1, verbose=0)>

# %%
X_train_rfe=rfe.transform(X_train)
X_val_rfe=rfe.transform(X_val)

# %%
rfe_model=model1.fit(X_train_rfe,Y_train)
rfe_pred=rfe_model.predict(X_val_rfe)

# %%
mean_squared_error(Y_val,rfe_pred)
# Out:
# 130.4727288382879

# %%
sub21=rfe_model.predict(test_data_rfe)

# %%
submission1=pd.DataFrame({'prediction':sub21})

# %%
submission1
# Out:
#      prediction
# 0    134.619203
# 1    190.750458
# 2    141.659896
# 3    164.562167
# 4    149.698195
# ..          ...
# 757  218.489854
# 758  190.299547
# 759  181.663413
# 760  200.969473
# 761  144.158719
#
# [762 rows x 1 columns]

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
def print_results(results):
    print('BEST PARAMS: {}\n'.format(results.best_params_))

    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print('{} (+/-{}) for {}'.format(round(mean, 3), round(std * 2, 3), params))

# %%
gbc = LinearRegression()
parameters = {
          'copy_X':[True,False],
          'fit_intercept':[True,False],
          'n_jobs':[None,-1],
          'normalize':[False,True]
}
rs = RandomizedSearchCV(gbc, parameters, cv=5,n_iter=12)
rs.fit(X_train, Y_train)

print_results(rs)
# Out:
# BEST PARAMS: {'normalize': False, 'n_jobs': None, 'fit_intercept': True, 'copy_X': False}
#
# 0.51 (+/-0.099) for {'normalize': True, 'n_jobs': None, 'fit_intercept': False, 'copy_X': True}
# 0.51 (+/-0.099) for {'normalize': True, 'n_jobs': None, 'fit_intercept': False, 'copy_X': False}
# 0.768 (+/-0.024) for {'normalize': True, 'n_jobs': -1, 'fit_intercept': True, 'copy_X': True}
# 0.768 (+/-0.024) for {'normalize': False, 'n_jobs': None, 'fit_intercept': True, 'copy_X': False}
# 0.768 (+/-0.024) for {'normalize': False, 'n_jobs': None, 'fit_intercept': True, 'copy_X': True}
# 0.768 (+/-0.024) for {'normalize': True, 'n_jobs': None, 'fit_intercept': True, 'copy_X': True}
# 0.768 (+/-0.024) for {'normalize': True, 'n_jobs': None, 'fit_intercept': True, 'copy_X': False}
# 0.51 (+/-0.099) for {'normalize': False, 'n_jobs': -1, 'fit_intercept': False, 'copy_X': False}
# 0.51 (+/-0.099) for {'normalize': False, 'n_jobs': None, 'fit_intercept': False, 'copy_X': False}
# ...

# %%
test_data_rfe=rfe.transform(test_data)

# %%
sub111=rfe_model.predict(test_data_rfe)

# %%
submission=pd.DataFrame({'prediction':sub111})

# %%
submission
# Out:
#      prediction
# 0    129.093097
# 1    191.930574
# 2    141.795321
# 3    176.878352
# 4    150.714811
# ..          ...
# 757  217.805746
# 758  190.366927
# 759  185.283142
# 760  200.780032
# 761  141.352025
#
# [762 rows x 1 columns]

# %%
submission.to_csv('CANCER00.csv',index=False)

# %%
submission[submission['prediction']<0].count
# Out:
# <bound method DataFrame.count of Empty DataFrame
# Columns: [prediction]
# Index: []>

# %%
test_data[test_data['MedianAge']>57].count
# Out:
# <bound method DataFrame.count of      avgAnnCount  avgDeathsPerYear  ...  PctMarriedHouseholds  BirthRate
# 4       3.292847          0.602060  ...             47.826087  10.029499
# 55      2.917506          2.514548  ...             46.795028   4.493937
# 162     2.883661          2.423246  ...             52.945686   3.127102
# 243     1.544068          1.079181  ...             46.769034   3.333333
# 271     2.539076          2.193125  ...             51.591360   4.194566
# 340     1.322219          1.079181  ...             51.515152   8.121019
# 374     2.884229          2.447158  ...             49.226681   5.488942
# 642     1.397940          1.000000  ...             36.829268   6.625097
# 686     3.135451          2.748963  ...             53.690715   4.954882
# 752     1.681241          1.230449  ...             47.560976   2.939068
# 759     2.269513          1.968483  ...             48.108966   4.012841
#
# [11 rows x 29 columns]>

# %%
submission.to_csv('CANCER4.csv',index=False)

# %%
from sklearn.ensemble import RandomForestRegressor
base_model2=RandomForestRegressor()
base_model2.fit(X_train,Y_train)
pred2=base_model2.predict(X_val)
pred12=base_model2.predict(X_train)

# %%
mean_squared_error(Y_val,pred2)
# Out:
# 330.73007364981964

# %%
sub2=base_model2.predict(test_data)

# %%
submission2=pd.DataFrame({'prediction':sub2})

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
base_model3=GradientBoostingRegressor()
base_model3.fit(X_train,Y_train)
pred3=base_model3.predict(X_val)
pred13=base_model3.predict(X_train)

# %%
mean_squared_error(Y_val,pred3)
# Out:
# 294.43745067672023

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
base_model4=AdaBoostRegressor()
base_model4.fit(X_train,Y_train)
pred4=base_model4.predict(X_val)
pred14=base_model4.predict(X_train)

# %%
mean_squared_error(Y_val,pred4)
# Out:
# 388.7092817050609

# %%
from sklearn import svm
base_model5=svm.SVR()
base_model5.fit(X_train,Y_train)
pred5=base_model5.predict(X_val)
pred15=base_model5.predict(X_train)

# %%
mean_squared_error(Y_val,pred5)
# Out:
# 538.5148067970061

# %%
from

# %%
submission2
# Out:
#      prediction
# 0       141.409
# 1       199.895
# 2       161.843
# 3       154.178
# 4       152.839
# ..          ...
# 757     213.857
# 758     187.169
# 759     188.040
# 760     198.576
# 761     152.004
#
# [762 rows x 1 columns]

# %%
submission2.to_csv('CANCER3.csv',index=False)
